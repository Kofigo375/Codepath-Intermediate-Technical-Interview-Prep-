# %%
## implementing a stack 

stack = [] 

#push items onto the stack
stack.append(2)
stack.append(1)


# pop items onto the stack 
popped_items = stack.pop()

print(popped_items)
print(stack)

# %%
## queue implementation 
from collections import  deque

queue = deque()

queue.append(1)
queue.append(3)
queue.append(8)

print(queue)

# %%
removed_element = queue.popleft()
print(removed_element)

# %%
## Two Pointer

# %%
## Opposite direction pointers
word = [2,4,7,5,1,8]
left_pointer = 0
right_pointer = len(word) - 1 
while left_pointer < right_pointer:
    pass
    left_pointer += 1
    right_pointer -= 1

# %%
## same direction pointer 
nums1 = [1,4,5]
nums2 = [2,3,6]

nums1_pointer = 0
nums2_pointer = 0

while nums1_pointer < len(nums1) and nums2_pointer < len(nums2):
    # if condition
        # do some operation
        nums1_pointer += 1
        
    #else:
        #do some operation
        nums2_pointer +=1

# %%
## swap index positions
pointer_one, pointer_two = pointer_two, pointer_one

# %%
## swap value in the index position
nums[pointer_one], nums[pointer_two] = nums[pointer_two], nums[pointer_one]
