# %%
name = "Nae"
name[0] = "K"
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 name = "Nae"
# ----> 2 name[0] = "K"
#       3 print(name)
#
# TypeError: 'str' object does not support item assignment
